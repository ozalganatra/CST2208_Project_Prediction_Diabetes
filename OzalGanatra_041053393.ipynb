# %% [markdown]
# # BISI CST2101 Project - Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe (also known as the Pima Indians). In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima Indian heritage.
#
# -----------------
# ## Objective
# -----------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima tribe by doing Exploratory Data Analysis.
#
# -------------------------
# ## Data Dictionary
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function which scores likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome : Class variable (0: person is not diabetic or 1: person is diabetic)

# %% [markdown]
# ### Q1: Import the necessary libraries and briefly explain the use of each library (1 Mark)

# %%
# remove _____ & write the appropriate library name

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# You don't have to explain about these libraries below
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 1:
# * Numpy: Numpy or ndaaray (n-dimensional array) is the collection of similar type() and functions for mathematical operations on          the arrays.
#
# * Pandas: Pandas is use for data maipulation and analysis.  One of the main feature od pandas is dataframe, can create a                   structured data  basically in tabular form(rows and columns).
#
# * Seaborn: Seabon funstions provide to create multiple plots. It is widely used for data visualisation. It is built on top of              Matloblib.
#
# * Matplotlib: Matplotlib offers a variety of tools for making static, animated, and interactive visualisations.
#
# * StandardScaler: StandardScaler is a preprocessing module from the scikit-learn library in Python used to scale numerical data.                   It is commonly used to normalize or standardize features in datasets.
#
# * LogisticRegression: It is a machine learning algorithm used for binary classification whre target variable is binary.
#
# * RandomForestClassifier: It is an ensemble learning method that combines multiple decision trees to create a single model that                           is more accurate and robust than any of the individual trees

# %% [markdown]
# ### Q2: Read the given dataset (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima = pd.read_csv("diabetes.csv")

# %% [markdown]
# ### Q3. Show the last 5 records of the dataset (1 Mark)

# %%
#remove ______ and write the appropriate number in the function

pima.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 995            2      173             79             32      474  35.504233
# 996           13      132             70             30      111  35.271769
# 997            3      132             87             44      156  34.794755
# 998            0      140              0              0        0  41.926693
# 999            4       93             59             35       93  45.914499
#
#      DiabetesPedigreeFunction  Age  Outcome
# 995                  0.402867   21        1
# 996                  0.168845   42        1
# 997                  0.765003   29        1
# 998                  0.209833   28        1
# 999                  0.737636   29        1

# %% [markdown]
# ### Q4. Show the first 5 records of the dataset (1 Mark)

# %%
#remove _____ & write the appropriate function name and the number of rows to get in the output

pima.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Q5. Find the dimension of the `pima` dataframe. What do you understand by the dimension of the dataset? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.shape
# Out:
# (1000, 9)

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 5: Dimension of the dataset is nothing but the rows and columns of the dataframes. For example, from the above output we have 1000 rows and 9 columns

# %% [markdown]
# ### Q6. Find the size of the `pima` dataframe. (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.size
# Out:
# 9000

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 6: Size of the dataframe is 9000 (1000 rows * 9 columns)

# %% [markdown]
# ### Q7. Display the data types of all the variables in the data set? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# ### Q8. Are there any missing values in the `pima` dataframe?  Which variables have missing values? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.isnull().values.any()
# Out:
# False

# %%
#alternate way of checking missing values
pima.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 8: No, there are no missing values in the pima dataframe.

# %% [markdown]
# ### Q9. Find the summary statistics for all variables except for  `'Outcome'` variable? Choose any one column/variable and explain all the statistical measures. (2 Marks)

# %%
#remove _____ & write the appropriate function name

pima.iloc[:,0:7].describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness      Insulin  \
# count  1000.000000  1000.00000    1000.000000    1000.000000  1000.000000
# mean      4.051000   125.21600      69.072000      20.755000    83.086000
# std       3.325576    32.27772      20.465328      16.008599   117.255326
# min       0.000000     0.00000       0.000000       0.000000     0.000000
# 25%       1.000000   102.00000      64.000000       0.000000     0.000000
# 50%       3.000000   122.00000      72.000000      24.000000    23.000000
# 75%       6.000000   146.00000      80.000000      33.000000   133.500000
# max      17.000000   199.00000     122.000000      99.000000   846.000000
#
#                BMI  DiabetesPedigreeFunction
# count  1000.000000               1000.000000
# mean     32.664772                  0.494090
# std       7.563614                  0.322158
# min       0.000000                  0.078000
# 25%      28.275000                  0.258750
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 9:
#
# For the BMI variable,
# * Count(Total number of BMI datapoints) of the datapoints are 1000.
# * Mean which is nothing the but the average of all the BMI datapoints and the average is 32.664.
# * Standard deviation is the amount of variability in a dataset. From the above information, std is 7.56 which is almost normally distributed.
# * Minimum value in the BMI datapoints is 0 whereas maximum value is 67.10.
# * 25% which is nothing but the lowest quartile range from the median i.e., 28.275.
# * 50% is nothing but the median value of the BMI i.e., 33.80 which almost same as Mean value.
# * 75% is nothing but the highest quartile range from the meadian i.e., 36.90
#   (Summary of 25%,50% and 75%: Most of the Datapoints ranges between 28.75 to 36.90 for the BMI variables)

# %% [markdown]
# ### Q10. Plot the distribution plot for the variable `'BloodPressure'`. Write your observations from the plot. (2 Marks)

# %%
#remove _____ & write the appropriate library name

sns.displot(pima['BloodPressure'], kind='kde')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 10: The distribution of blodpressure is Bimodal distribution because it has 2 highest peak one at 0.005 and other at 0.030.

# %% [markdown]
# ### Q11. What is the `'BMI'` for the person having the highest `'Glucose'`? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima[pima['Glucose']==pima['Glucose'].max()]['BMI']
# Out:
# 661    42.9
# Name: BMI, dtype: float64

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 11: BMI for the person having the highest Glucose : 42.9

# %% [markdown]
# ### Q12.
# #### 12.1 What is the mean of the variable `'BMI'`?
# #### 12.2 What is the median of the variable `'BMI'`?
# #### 12.3 What is the mode of the variable `'BMI'`?
# #### 12.4 Are the three measures of central tendency equal?
#
# ### (2 Marks)

# %%
#remove _____ & write the appropriate function name

m1 = pima['BMI'].mean()  #Mean
print(m1)
m2 = pima['BMI'].median()  #Median
print(m2)
m3 = pima['BMI'].mode()[0]  #Mode
print(m3)
# Out:
# 32.664772391408796
# 32.8
# 32.0

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 12:
# 12.1 What is the mean of the variable 'BMI'?
# Ans: 32.66
#
# 12.2 What is the median of the variable 'BMI'?
# Ans: 32.8
#
# 12.3 What is the mode of the variable 'BMI'?
# Ans: 32.0
#
# 12.4 Are the three measures of central tendency equal?
# Ans: Yes, the three measures of central tendency are almost equal.

# %% [markdown]
# ### Q13. How many women's `'Glucose'` level is above the mean level of `'Glucose'`? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima[pima['Glucose']>pima['Glucose'].mean()].shape[0]
# Out:
# 449

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 13: 449 women's Glucose level is above the mean level of Glucose

# %% [markdown]
# ### Q14. Create the pairplot for variables `'Glucose'`, `'SkinThickness'` and `'DiabetesPedigreeFunction'`. Write you observations from the plot. (2 Marks)

# %%
#remove _____ & write the appropriate function and argument names

sns.pairplot(data=pima, vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 14:
#
# Distribution:
#
# Glucose is normally distributed.
# SkinThickness has bimodal distribution.
# DiabetesPedigreeFunction is right skewed.
#
# Relationship between the variables,
#
# Glucose and SkinThickness: There is no relationship among each other.
# Glucose and DiabetesPedigreeFunction: There is no relationship among each other.
# SkinThickness and DiabetesPedigreeFunction: There is no relationship among each other.

# %% [markdown]
# ### Q15. Plot the scatterplot between `'Glucose'` and `'Insulin'`. Write your observations from the plot. (1 Mark)

# %%
#remove _____ & write the appropriate function name

sns.scatterplot(x='Glucose',y='Insulin',data=pima, color='green')
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Insulin'>

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 15: From the sactter plot, we can depicts that the Glucose and Insulin are positively correlated. If the patient's glucose level is high then the doses of insulin is also increases.

# %% [markdown]
# ### Q16. Plot the boxplot for the 'Age' variable. Are there outliers? (1 Mark)

# %%
#remove _____ & write the appropriate function and column name 

plt.boxplot(pima['Age'])

plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 16:There are many outliers in the Age variable.

# %% [markdown]
# ### Q17. Find and visualize the the correlation matrix. Write your observations from the plot. (1 Mark)

# %%
#remove _____ & write the appropriate function name and run the code

corr_matrix = pima.iloc[:,0:8].corr()

corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.112930       0.127463      -0.080033
# Glucose                      0.112930  1.000000       0.134993       0.050656
# BloodPressure                0.127463  0.134993       1.000000       0.249063
# SkinThickness               -0.080033  0.050656       0.249063       1.000000
# Insulin                     -0.064909  0.334175       0.117369       0.472663
# BMI                          0.012920  0.222138       0.247275       0.387055
# DiabetesPedigreeFunction    -0.025452  0.127004       0.059303       0.214026
# Age                          0.548665  0.255567       0.240416      -0.121236
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.064909  0.012920                 -0.025452
# Glucose                   0.334175  0.222138                  0.127004
# ...

# %%
#remove _____ & write the appropriate function name

plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix, annot = True, cmap='Greens')

# display the plot
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 17: Correlation value between age and preganancies is 0.55 which can be considered as moderately correlated. And the correlation value between Insulin and SkinThickness is 0.47 which can be considered as low correlated.

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Q18. Split and scale the data (2 Mark)

# %%
# Split the data into dependent and independent variables
# remove _____ & write the appropriate function variable name
y = pima.Outcome
x = pima.drop('Outcome', axis = 1)

# %%
# Using StandarScaler scale the data
# remove _____ & write the appropriate function function name

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(x)

# %%
# Splitting the data into train and test. Use test size as 15%
# remove _____ & complete the code

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15, stratify=y,  random_state = 45)

# %%
#checking the dimension of the split data
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((850, 8), (150, 8), (850,), (150,))

# %% [markdown]
# ### Q19. Train a Logistic Regression Model. What is the Accuracy and how many True Positives and True Negatives did you get? (3 Marks)

# %%
# remove _____ & complete the code

# import the model
from sklearn.linear_model import LogisticRegression

# Instantiate the model
lr = LogisticRegression()

# fit the model on the train set
m = lr.fit(x_train, y_train)

# Predict on x_test
y_pred = m.predict(x_test)

# Evaluate the model
print('Accuracy of Logistic Regression model on the train set: {:.2f}'.format(m.score(x_train, y_train)))
print('Accuracy of the Logictic Regression model on the test set: {:.2f}'.format(m.score(x_test, y_test)))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# Accuracy of Logistic Regression model on the train set: 0.76
# Accuracy of the Logictic Regression model on the test set: 0.75
# C:\Users\ozal\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([[63, 12],
#        [26, 49]], dtype=int64)

# %%
#Plotting the heatmap of Confusion matrix

sns.heatmap(cm, annot=True, cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
#For reference

#cm[0][0] = TP
#cm[1][1] = TN
#cm[0][1] = FP
#cm[1][0] = FN

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 19:
#
# * Accuracy of train and test dataset are 76% and 75%.
#
# * True Positives : 63 and True Negatives : 49

# %% [markdown]
# ### Q20. Train a Random Forest Model. What is the Accuracy and how many True Positives and True Negatives did you get? (3 Marks)

# %%
#remove _____ & complete the code

# Import the Model
from sklearn.ensemble import RandomForestClassifier

# Instantiate the model. 
rf = RandomForestClassifier(n_estimators=301, max_depth=3)

# fit the model on the train set
m2 = rf.fit(x_train, y_train)

# Predict on x_test
y_pred2 = m2.predict(x_test)

# Evaluate the Model
print('Accuracy of Random Forest model on the train set: {:.2f}'.format(m2.score(x_train, y_train)))
print('Accuracy of Random Forest model on the test set: {:.2f}'.format(m2.score(x_test, y_test)))
cm_rf = confusion_matrix(y_test, y_pred2)
cm_rf
# Out:
# Accuracy of Random Forest model on the train set: 0.82
# Accuracy of Random Forest model on the test set: 0.77
# array([[57, 18],
#        [16, 59]], dtype=int64)

# %%
#Plotting the heatmap of Confusion matrix

sns.heatmap(cm_rf, annot=True, cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 20:
#
# * Accuracy of train and test dataset are 82% and 77%.
#
# * True Positives : 57 and True Negatives : 59

# %% [markdown]
# ### Q21. Which model performed better? (1 Mark)

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 21: Random Forest model peformed better
